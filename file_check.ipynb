# %%
import pandas as pd

address='/u50/zhanh279/4Z03/jupyter/Results/combined_dataset.csv'
df=pd.read_csv(address)
print(df.columns)
# Out:
# Index(['user_id', 'target', 'type', 'title', 'body', 'created_utc',
#        'submission_id', 'parent_id', 'comment_id', 'Depression'],
#       dtype='object')
